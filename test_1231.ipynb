# %% [markdown]
# ## pandas groupby
# ### 그룹별로 개수 세는 과정
# #### count 대신 다른 연산으로 응용 가능

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c523f542-3423-484f-a1ee-7b73f7d974cf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c523f542-3423-484f-a1ee-7b73f7d974cf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test_1231.csv to test_1231 (1).csv

# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
import io
df = pd.read_csv('test_1231.csv', encoding = "cp949", engine='python')
df
# Out:
#     구분  무엇
# 0   1월   1
# 1   1월   2
# 2   1월   3
# 3   1월   1
# 4   1월   2
# 5   1월   2
# 6   1월   4
# 7   1월   1
# 8   1월   1
# 9   1월   2
# 10  1월   3
# 11  1월   1
# 12  1월   2
# 13  1월   2
# 14  1월   4
# 15  1월   1
# 16  2월   4
# 17  2월   1
# 18  2월   1
# 19  2월   2
# 20  2월   3
# 21  2월   1
# 22  2월   2
# 23  2월   2
# 24  2월   4
# 25  2월   1
# 26  3월   5
# 27  3월   8
# 28  3월   1
# 29  3월   4
# 30  3월   5
# 31  3월   6
# 32  3월   2
# 33  3월   3
# 34  3월   4
# 35  3월   2
# 36  3월   2
# 37  3월   9
# 38  3월   6
# 39  4월   1
# 40  4월   7
# 41  4월   3
# 42  4월   6
# 43  4월   6
# 44  4월   2
# 45  4월   9
# 46  4월   3
# 47  4월   1
# 48  4월   4
# 49  4월   4

# %%
df.groupby('구분').count()
# Out:
#     무엇
# 구분
# 1월  16
# 2월  10
# 3월  13
# 4월  11
